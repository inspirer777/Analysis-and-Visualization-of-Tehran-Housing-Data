# %% [markdown]
# # code part 1

# %%
import pandas as pd 
#df9502 = pd.read_excel('all.xlsx')
#df9502

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', None)
df9502

# %%
df9501 = pd.read_excel('Iran_maskan_koll9501.xlsx')
df9501.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9501.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9501.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9501.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9501.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9501.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9501.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9501.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9501.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9501.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9501.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9501.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9501.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9501.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9501.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9501.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9501 = df9501.drop(0)
df9501 = df9501.drop(1)
df9501 = df9501.drop(2)
df9501
# Out:
#       codegharadas  noe_ghardad    ostan sharestam   noe_melk  \
# 3         13333003  مبايعه نامه   tehran    پاكدشت  aparteman
# 4         13333005  مبايعه نامه    تهران     تهران  aparteman
# 5         13333014  مبايعه نامه  كردستان       سقز  aparteman
# 6         13333018  مبايعه نامه    تهران     تهران  aparteman
# 7         13333026  مبايعه نامه    البرز       کرج  aparteman
# ...            ...          ...      ...       ...        ...
# 15022     13405950  مبايعه نامه    تهران     تهران  aparteman
# 15023     13405976  مبايعه نامه     فارس     شيراز  aparteman
# 15024     13405987  مبايعه نامه    تهران     ملارد  aparteman
# 15025     13405988  مبايعه نامه    مرکزی      اراك  aparteman
# 15026     13405990  مبايعه نامه    تهران     تهران  aparteman
#
#       managhe_shahrdari Noe_karbari masahat darsad   gheymat  \
# 3                   NaN      مسکوني      60    100    300000
# 4                    14      مسکوني   70.63    100   2540000
# ...

# %%
df9502 = pd.read_excel('Iran_maskan_koll9502.xlsx')
df9502.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9502.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9502.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9502.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9502.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9502.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9502.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9502.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9502.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9502.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9502.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9502.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9502.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9502.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9502.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9502.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9502 = df9502.drop(0)
df9502 = df9502.drop(1)
df9502 = df9502.drop(2)
df9502
# Out:
#       codegharadas  noe_ghardad           ostan sharestam         noe_melk  \
# 3         13405324  مبايعه نامه           مرکزی    دليجان  دستگاه آپارتمان
# 4         13405340  مبايعه نامه           گیلان       رشت  دستگاه آپارتمان
# 5         13405345  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 6         13405364  مبايعه نامه           تهران        ري  دستگاه آپارتمان
# 7         13405385  مبايعه نامه          اردبیل    اردبيل  دستگاه آپارتمان
# ...            ...          ...             ...       ...              ...
# 32459     13540329  مبايعه نامه          اردبیل    اردبيل  دستگاه آپارتمان
# 32460     13540338  مبايعه نامه           تهران        ري  دستگاه آپارتمان
# 32461     13540342  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 32462     13540344  مبايعه نامه           قزوین     قزوين  دستگاه آپارتمان
# 32463     13540358  مبايعه نامه  آذربایجان شرقی     تبريز  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# ...

# %%
df9503 = pd.read_excel('Iran_maskan_koll9503.xlsx')
df9503.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9503.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9503.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9503.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9503.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9503.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9503.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9503.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9503.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9503.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9503.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9503.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9503.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9503.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9503.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9503.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9503 = df9503.drop(0)
df9503 = df9503.drop(1)
df9503 = df9503.drop(2)
df9503
# Out:
#       codegharadas  noe_ghardad   ostan sharestam         noe_melk  \
# 3         13540369  مبايعه نامه   بوشهر     بوشهر  دستگاه آپارتمان
# 4         13540373  مبايعه نامه   البرز       کرج  دستگاه آپارتمان
# 5         13540375  مبايعه نامه   البرز       کرج  دستگاه آپارتمان
# 6         13540377  مبايعه نامه   تهران     تهران  دستگاه آپارتمان
# 7         13540387  مبايعه نامه   تهران     تهران  دستگاه آپارتمان
# ...            ...          ...     ...       ...              ...
# 32265     13696829  مبايعه نامه   گیلان       رشت  دستگاه آپارتمان
# 32266     13696837  مبايعه نامه   تهران     تهران  دستگاه آپارتمان
# 32267     13696839  مبايعه نامه   البرز       کرج  دستگاه آپارتمان
# 32268     13696849  مبايعه نامه      قم        قم  دستگاه آپارتمان
# 32269     13696869  مبايعه نامه  اصفهان    اصفهان  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# 3                     2      مسکوني     136    100  4600000
# ...

# %%
df9504 = pd.read_excel('Iran_maskan_koll9504.xlsx')
df9504.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9504.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9504.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9504.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9504.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9504.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9504.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9504.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9504.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9504.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9504.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9504.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9504.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9504.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9504.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9504.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9504 = df9504.drop(0)
df9504 = df9504.drop(1)
df9504 = df9504.drop(2)
df9504
# Out:
#       codegharadas  noe_ghardad           ostan sharestam         noe_melk  \
# 3         13696878  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 4         13696879  مبايعه نامه  آذربایجان شرقی     تبريز  دستگاه آپارتمان
# 5         13696887  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 6         13696889  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 7         13696893  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# ...            ...          ...             ...       ...              ...
# 30467     13836418  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 30468     13836421  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 30469     13836428  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 30470     13836432  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 30471     13832639  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# ...

# %%
df9505 = pd.read_excel('Iran_maskan_koll9505.xlsx')
df9505.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9505.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9505.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9505.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9505.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9505.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9505.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9505.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9505.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9505.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9505.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9505.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9505.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9505.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9505.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9505.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9505 = df9505.drop(0)
df9505 = df9505.drop(1)
df9505 = df9505.drop(2)
df9505
# Out:
#       codegharadas  noe_ghardad           ostan sharestam         noe_melk  \
# 3         13836440  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 4         13836451  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 5         13836452  مبايعه نامه  آذربایجان غربی  مياندوآب  دستگاه آپارتمان
# 6         13836453  مبايعه نامه           گیلان       رشت  دستگاه آپارتمان
# 7         13836462  مبايعه نامه         كردستان     سنندج  دستگاه آپارتمان
# ...            ...          ...             ...       ...              ...
# 34223     13985559  مبايعه نامه          اردبیل     خلخال  دستگاه آپارتمان
# 34224     13985575  مبايعه نامه           گیلان       رشت  دستگاه آپارتمان
# 34225     13985586  مبايعه نامه            فارس     شيراز  دستگاه آپارتمان
# 34226     13985591  مبايعه نامه        مازندران      بابل  دستگاه آپارتمان
# 34227     13985599  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad   gheymat  \
# ...

# %%
df9506 = pd.read_excel('Iran_maskan_koll9506.xlsx')
df9506.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9506.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9506.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9506.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9506.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9506.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9506.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9506.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9506.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9506.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9506.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9506.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9506.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9506.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9506.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9506.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9506 = df9506.drop(0)
df9506 = df9506.drop(1)
df9506 = df9506.drop(2)
df9506
# Out:
#       codegharadas  noe_ghardad  ostan sharestam         noe_melk  \
# 3         13985615  مبايعه نامه  تهران  اسلامشهر  دستگاه آپارتمان
# 4         13985616  مبايعه نامه  تهران     تهران  دستگاه آپارتمان
# 5         13985618  مبايعه نامه  البرز  نظر آباد  دستگاه آپارتمان
# 6         13985627  مبايعه نامه  تهران     تهران  دستگاه آپارتمان
# 7         13985629  مبايعه نامه  البرز       کرج  دستگاه آپارتمان
# ...            ...          ...    ...       ...              ...
# 29240     14115036  مبايعه نامه  تهران     تهران  دستگاه آپارتمان
# 29241     14115047  مبايعه نامه  البرز       کرج  دستگاه آپارتمان
# 29242     14115054  مبايعه نامه  البرز       کرج  دستگاه آپارتمان
# 29243     14115056  مبايعه نامه  قزوین     قزوين  دستگاه آپارتمان
# 29244     14115065  مبايعه نامه  تهران     تهران  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad   gheymat  \
# 3                   NaN      مسکوني      78    100    655000
# ...

# %%
df9507 = pd.read_excel('Iran_maskan_koll9507.xlsx')
df9507.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9507.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9507.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9507.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9507.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9507.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9507.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9507.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9507.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9507.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9507.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9507.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9507.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9507.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9507.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9507.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9507 = df9507.drop(0)
df9507 = df9507.drop(1)
df9507 = df9507.drop(2)
df9507
# Out:
#       codegharadas  noe_ghardad           ostan sharestam         noe_melk  \
# 3         14115085  مبايعه نامه           سمنان     سمنان  دستگاه آپارتمان
# 4         14115089  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 5         14115091  مبايعه نامه            فارس     شيراز  دستگاه آپارتمان
# 6         14115105  مبايعه نامه           كرمان     كرمان  دستگاه آپارتمان
# 7         14115108  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# ...            ...          ...             ...       ...              ...
# 21752     14219943  مبايعه نامه         خوزستان     اهواز  دستگاه آپارتمان
# 21753     14219949  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 21754     14219950  مبايعه نامه  آذربایجان شرقی     تبريز  دستگاه آپارتمان
# 21755     14219975  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 21756     14219985  مبايعه نامه  آذربایجان شرقی     تبريز  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# ...

# %%
df9508 = pd.read_excel('Iran_maskan_koll9508.xlsx')
df9508.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9508.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9508.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9508.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9508.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9508.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9508.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9508.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9508.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9508.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9508.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9508.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9508.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9508.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9508.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9508.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9508 = df9508.drop(0)
df9508 = df9508.drop(1)
df9508 = df9508.drop(2)
df9508
# Out:
#       codegharadas  noe_ghardad           ostan sharestam         noe_melk  \
# 3         14220002  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 4         14220004  مبايعه نامه           مرکزی    كميجان  دستگاه آپارتمان
# 5         14220006  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 6         14220009  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 7         14220015  مبايعه نامه            فارس     شيراز  دستگاه آپارتمان
# ...            ...          ...             ...       ...              ...
# 25066     14334307  مبايعه نامه  آذربایجان شرقی     تبريز  دستگاه آپارتمان
# 25067     14334308  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 25068     14334311  مبايعه نامه           البرز       کرج  دستگاه آپارتمان
# 25069     14334322  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
# 25070     14334326  مبايعه نامه           تهران     تهران  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad   gheymat  \
# ...

# %%
df9509 = pd.read_excel('Iran_maskan_koll9509.xlsx')
df9509.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df9509.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df9509.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df9509.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df9509.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df9509.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df9509.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df9509.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df9509.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df9509.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df9509.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df9509.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df9509.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df9509.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df9509.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df9509.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df9509 = df9509.drop(0)
df9509 = df9509.drop(1)
df9509 = df9509.drop(2)
df9509
# Out:
#       codegharadas  noe_ghardad     ostan sharestam         noe_melk  \
# 3         14334342  مبايعه نامه     تهران  اسلامشهر  دستگاه آپارتمان
# 4         14334343  مبايعه نامه     تهران     تهران  دستگاه آپارتمان
# 5         14334347  مبايعه نامه  كرمانشاه  كرمانشاه  دستگاه آپارتمان
# 6         14334348  مبايعه نامه     تهران     تهران  دستگاه آپارتمان
# 7         14334360  مبايعه نامه  مازندران      بابل  دستگاه آپارتمان
# ...            ...          ...       ...       ...              ...
# 23256     14435011  مبايعه نامه     تهران     تهران  دستگاه آپارتمان
# 23257     14435015  مبايعه نامه     سمنان    گرمسار  دستگاه آپارتمان
# 23258     14435029  مبايعه نامه   كردستان     سنندج  دستگاه آپارتمان
# 23259     14435042  مبايعه نامه     البرز       کرج  دستگاه آپارتمان
# 23260     14435062  مبايعه نامه     مرکزی      اراك  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# 3                   NaN      مسکوني      55    100   465000
# ...

# %%
df95010 = pd.read_excel('Iran_maskan_koll9510.xlsx')
df95010.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df95010.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df95010.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df95010.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df95010.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df95010.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df95010.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df95010.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df95010.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df95010.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df95010.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df95010.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df95010.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df95010.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df95010.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df95010.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df95010 = df95010.drop(0)
df95010 = df95010.drop(1)
df95010 = df95010.drop(2)
df95010
# Out:
#       codegharadas  noe_ghardad           ostan  sharestam         noe_melk  \
# 3         14436482  مبايعه نامه  آذربایجان غربی     اروميه  دستگاه آپارتمان
# 4         14436490  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
# 5         14436492  مبايعه نامه         هرمزگان  بندر عباس  دستگاه آپارتمان
# 6         14436496  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
# 7         14436500  مبايعه نامه           البرز        کرج  دستگاه آپارتمان
# ...            ...          ...             ...        ...              ...
# 32073     14559231  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
# 32074     14559237  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
# 32075     14559240  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
# 32076     14559242  مبايعه نامه           البرز        کرج  دستگاه آپارتمان
# 32077     14559243  مبايعه نامه           تهران      تهران  دستگاه آپارتمان
#
# ...

# %%
df95011 = pd.read_excel('Iran_maskan_koll9511.xlsx')
df95011.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df95011.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df95011.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df95011.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df95011.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df95011.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df95011.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df95011.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df95011.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df95011.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df95011.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df95011.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df95011.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df95011.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df95011.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df95011.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df95011 = df95011.drop(0)
df95011 = df95011.drop(1)
df95011 = df95011.drop(2)
df95011
# Out:
#       codegharadas  noe_ghardad        ostan sharestam         noe_melk  \
# 3         14559247  مبايعه نامه        تهران     تهران  دستگاه آپارتمان
# 4         14559249  مبايعه نامه        تهران     تهران  دستگاه آپارتمان
# 5         14559251  مبايعه نامه        البرز       کرج  دستگاه آپارتمان
# 6         14559254  مبايعه نامه  خراسان رضوی      مشهد  دستگاه آپارتمان
# 7         14559261  مبايعه نامه         فارس     شيراز  دستگاه آپارتمان
# ...            ...          ...          ...       ...              ...
# 30774     14679509  مبايعه نامه     مازندران  قائم شهر  دستگاه آپارتمان
# 30775     14679511  مبايعه نامه        البرز       کرج  دستگاه آپارتمان
# 30776     14679518  مبايعه نامه        تهران     تهران  دستگاه آپارتمان
# 30777     14679522  مبايعه نامه           قم        قم  دستگاه آپارتمان
# 30778     14677291  مبايعه نامه        تهران     تهران  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# ...

# %%
df95012 = pd.read_excel('Iran_maskan_koll9512.xlsx')
df95012.drop(['Unnamed: 0','Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
df95012.rename(columns={'Unnamed: 17': 'codeposti'}, inplace=True)
df95012.rename(columns={'Unnamed: 3': 'codegharadas'}, inplace=True)
df95012.rename(columns={'Unnamed: 4': 'noe_ghardad'}, inplace=True)
df95012.rename(columns={'Unnamed: 5': 'ostan'}, inplace=True)
df95012.rename(columns={'Unnamed: 6': 'sharestam'}, inplace=True)
df95012.rename(columns={'Unnamed: 7': 'noe_melk'}, inplace=True)
df95012.rename(columns={'Unnamed: 8': 'managhe_shahrdari'},inplace=True)
df95012.rename(columns={'Unnamed: 9': 'Noe_karbari'}, inplace=True)
df95012.rename(columns={'Unnamed: 10': 'masahat'}, inplace=True)
df95012.rename(columns={'Unnamed: 11': 'darsad'}, inplace=True)
df95012.rename(columns={'Unnamed: 12': 'gheymat'}, inplace=True)
df95012.rename(columns={'Unnamed: 13': 'gheymat_1_metr_moraba'}, inplace=True)
df95012.rename(columns={'Unnamed: 14': 'age_bana'}, inplace=True)
df95012.rename(columns={'Unnamed: 15': 'noe_eskelet'}, inplace=True)
df95012.rename(columns={'Unnamed: 16': 'tarikh_sabt_gharardad'}, inplace=True)
df95012 = df95012.drop(0)
df95012 = df95012.drop(1)
df95012 = df95012.drop(2)
df95012
# Out:
#       codegharadas  noe_ghardad     ostan  sharestam         noe_melk  \
# 3         14679535  مبايعه نامه     تهران      تهران  دستگاه آپارتمان
# 4         14679540  مبايعه نامه     تهران      تهران  دستگاه آپارتمان
# 5         14679544  مبايعه نامه     البرز        کرج  دستگاه آپارتمان
# 6         14679547  مبايعه نامه     تهران      تهران  دستگاه آپارتمان
# 7         14679554  مبايعه نامه  مازندران      زيرآب  دستگاه آپارتمان
# ...            ...          ...       ...        ...              ...
# 25239     14784816  مبايعه نامه     تهران      تهران  دستگاه آپارتمان
# 25240     14784820  مبايعه نامه     البرز        کرج  دستگاه آپارتمان
# 25241     14784826  مبايعه نامه    اصفهان  شاهين شهر  دستگاه آپارتمان
# 25242     14784832  مبايعه نامه   كردستان        سقز  دستگاه آپارتمان
# 25243     14784841  مبايعه نامه     تهران  چهاردانگه  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad  gheymat  \
# 3                     5      مسکوني  139.98    100  8000000
# ...

# %%
result = pd.concat([df9501, df9502,df9503,df9504,df9505,df9506,df9507,df9508,df9509,df95010,df95011,df95012], axis=0)
result
# Out:
#       codegharadas  noe_ghardad    ostan  sharestam         noe_melk  \
# 3         13333003  مبايعه نامه   tehran     پاكدشت        aparteman
# 4         13333005  مبايعه نامه    تهران      تهران        aparteman
# 5         13333014  مبايعه نامه  كردستان        سقز        aparteman
# 6         13333018  مبايعه نامه    تهران      تهران        aparteman
# 7         13333026  مبايعه نامه    البرز        کرج        aparteman
# ...            ...          ...      ...        ...              ...
# 25239     14784816  مبايعه نامه    تهران      تهران  دستگاه آپارتمان
# 25240     14784820  مبايعه نامه    البرز        کرج  دستگاه آپارتمان
# 25241     14784826  مبايعه نامه   اصفهان  شاهين شهر  دستگاه آپارتمان
# 25242     14784832  مبايعه نامه  كردستان        سقز  دستگاه آپارتمان
# 25243     14784841  مبايعه نامه    تهران  چهاردانگه  دستگاه آپارتمان
#
#       managhe_shahrdari Noe_karbari masahat darsad   gheymat  \
# 3                   NaN      مسکوني      60    100    300000
# ...

# %% [markdown]
# # خروجی اکسل

# %%
result.to_excel('final.xlsx', engine='openpyxl')
